# %%
import pydicom
import matplotlib.pyplot as plt

# %%
filename = '/lfs/1/gangus/data/mimic/physionet.org/files/mimic-cxr/2.0.0/files/p10/p10000980/s54980801/a75a1fbe-802065ad-717eb7c1-e2ce3552-646276a6.dcm'
dcm = pydicom.dcmread(filename)
plt.figure(figsize=(10,10))
plt.imshow(dcm.pixel_array, cmap=plt.cm.bone)
